# %% [markdown]
# #### Q1
#
# -  Import `matplotlib.pyplot` as `plt` and set `%matplotlib inline` if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?
#
# inline will show _static_ images of the plot. If you are not using Jupyter Notebook you will need to install matplotlib through pip and then run in on your other IDE/service.
#
# - what does `%matplotlib notebook` does?
#
# %matplotlib notebook will show interactive plots embedded on the notebook

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Q2 Plot the following two plot using the data given in ypoints

# %%
import matplotlib.pyplot as plt
import numpy as np



ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# #### Q3 Modify the above plot as shown in the following figure

# %%
# Plot the follwing plot and place th etitle as shown: 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.title("Title")

plt.show()

# %% [markdown]
# #### Q4 Show only grid on the x axis

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.grid(axis="x")

plt.show()

# %% [markdown]
# #### Q5 Create the following histogram. You can use any color.

# %%
# Creating an array
array = np.random.normal(0, 1, 10000)

plt.hist(array, color='r')
plt.show()

# %% [markdown]
# #### Q6 Create the follwing using subplots. Adjust the spacing. Play with Labels and title

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %% [markdown]
# Create the following graph using the following properties
#
# We can configure the ranges of the axes using the set_ylim and set_xlim methods in the axis object, or axis('tight') for automatically getting "tightly fitted" axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize = (15, 5))

axes[0].plot(x, x ** 2, x, x ** 3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x ** 2, x, x ** 3)
axes[1].axis('tight')
axes[1].set_title("tighly fitted axes")

axes[2].plot(x, x ** 2, x, x ** 3)
axes[2].set_ylim([0, 120])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");
